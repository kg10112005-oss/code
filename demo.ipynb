# %% [markdown]
# # MyPackage Demo Notebook
#
# This notebook demonstrates how to install and run your custom Python package `mypackage` directly in Jupyter.

# %%
# Step 1: Install your local package directly inside Jupyter Notebook
# %pip install -e .

# %%
# Step 2: Import your package
import mypackage

# Check available functions
dir(mypackage)

# %%
# Step 3: Run Program 1 (Skip-Gram Word Embeddings with PyTorch & t-SNE)
mypackage.program1()

# %%
# Step 4: Run Program 2 (Iris Dataset Classifier with Keras)
mypackage.program2()

# %%
# Step 5: Run Program 3 (CIFAR-10 CNN Image Classification with Keras)
mypackage.program3()

# %%
# Step 6: Run Program 4 (MNIST Autoencoder with Keras)
mypackage.program4()
